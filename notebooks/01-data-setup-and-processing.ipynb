# %% [markdown]
# ## Data Setup and Processing
#
# Load the dataset, apply initial preprocessing (resizing/normalization/etc.), and prepare the data structures/splits used by the later training notebooks.

# %%
import sys
from pathlib import Path

# Make project root importable.
sys.path.append(str(Path().resolve()))

import src.utils as utils
import src.data_loading as data_loading
