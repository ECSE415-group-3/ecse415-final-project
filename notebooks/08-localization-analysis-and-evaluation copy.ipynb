# %% [markdown]
# ## Localization Analysis and Evaluation
#
# Compute localization metrics from the localization pipeline outputs and analyze representative failure/success cases.

# %%
import sys
from pathlib import Path

# Make project root importable.
sys.path.append(str(Path().resolve()))

import src.utils as utils
import src.localization_evaluation as localization_evaluation
