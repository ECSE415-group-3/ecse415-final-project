# %% [markdown]
# ## Analysis and Evaluation
#
# Aggregate evaluation results across model options and runs. Include error analysis, relevant plots/tables, and a concise summary of findings.

# %%
import sys
from pathlib import Path

# Make project root importable.
sys.path.append(str(Path().resolve()))

import src.utils as utils
