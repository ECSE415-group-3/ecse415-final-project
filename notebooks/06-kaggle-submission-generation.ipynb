# %% [markdown]
# ## Kaggle Submission Generation
#
# Generate the final Kaggle-ready predictions/output file. Document the model used and the steps used to produce the submission.

# %%
import sys
from pathlib import Path

# Make project root importable.
sys.path.append(str(Path().resolve()))

import src.utils as utils
import src.kaggle_submission as kaggle_submission
